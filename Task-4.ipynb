# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# ## Task-4:Exploratory Data Analysis - Terrorism

# %% [markdown]
# ## Problem Statements:

# %% [markdown]
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’.
#
# ● As a security/defense analyst, try to find out the hot zone of terrorism.
#
# ● What all security issues and insights you can derive by EDA?

# %% [markdown]
# ### By: Abhay Pratap Singh Chauhan(Data Science Intern,GRIPJULY2021)

# %% [markdown]
# # Steps:

# %% [markdown]
# 1. Importing Libraries and DataSet
#
# 2. Data Visualization
#
# 3. Data Analysis
#
# 4. Conclusion

# %% [markdown]
# ### Step:1 Importing Libraries and DataSet

# %%
#importing Librarires
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wg
wg.filterwarnings("ignore")

# %%
sns.color_palette("tab10")
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ## Step2: Multivariate Visualization

# %%
#correlation matrix and heatmap
datacorr=df.corr()
datacorr
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
plt.figure(figsize=(30,30))
small=df.drop(['latitude','longitude','specificity'],axis=1)
small=small.iloc[15:,15:]
smallcorr=small.corr()
sns.heatmap(smallcorr,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,20))
sns.heatmap(datacorr.iloc[:15,:15],annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(21,5))
sns.countplot(df['iyear'])
plt.title('obeservation in no. of events with years')
# Out:
# Text(0.5, 1.0, 'obeservation in no. of events with years')

# %%
sns.countplot(df['extended'])
plt.title('incident extended more than 24 hours or not')
# Out:
# Text(0.5, 1.0, 'incident extended more than 24 hours or not')

# %%
f=plt.figure(figsize=(20,5))
f.add_subplot(121)
#the attack with criterion-political,economic,religious,social cause
sns.countplot(df['crit1'])
plt.title('Inclusion Criteria of Attack')

f.add_subplot(122)
sns.countplot(df['multiple'])
plt.title('Number of attacks which were part of multiple incidents')
# Out:
# Text(0.5, 1.0, 'Number of attacks which were part of multiple incidents')

# %%
len(df['country_txt'])
# Out:
# 181691

# %%
f=plt.figure(figsize=(30,10))
sns.countplot(df['country_txt'].iloc[:100])
# Out:
# <AxesSubplot:xlabel='country_txt', ylabel='count'>

# %%
len(df[df['country_txt']=='United States'])
# Out:
# 2836

# %%
df['country_txt'].value_counts()
# Out:
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Antigua and Barbuda        1
# Vatican City               1
# Falkland Islands           1
# St. Lucia                  1
# South Vietnam              1
# Name: country_txt, Length: 205, dtype: int64

# %%
f=plt.figure(figsize=(40,10))
sns.countplot(df['country_txt'][:181691])
# Out:
# <AxesSubplot:xlabel='country_txt', ylabel='count'>

# %%
df['region'].unique()
#1.North America
#2.Central America and Carribean
#3.South America
#4.East Asia
#5.Southeast Asia
#6.South Asia
#7.Central Asia
#8.Western Europe
#9.Eastern Europe
#10.MIddle East & North Africa
#11.Sub_Saharan Africa
#12.Australia and Oceania
# Out:
# array([ 2,  1,  5,  8,  4,  3,  9, 11, 10, 12,  6,  7], dtype=int64)

# %%
sns.countplot(df['region'])
#region 10_middle east and North Africa have reported to have more incidents
#followed by south asia(region 6)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
df['attacktype1'].unique()
#1.Assasination
#2.Armed Assault
#3.Bombing/Explosion
#4.Hijacking
#5.Hostage Taking(Barricode Incident)
#6.Hostage Taking(KIdnapping)
#7.Facility/Infrastructure Attack
#8. Unarmed Assault
#9.Unknown
# Out:
# array([1, 6, 3, 7, 2, 4, 9, 8, 5], dtype=int64)

# %%
sns.countplot(df['attacktype1'])
# Out:
# <AxesSubplot:xlabel='attacktype1', ylabel='count'>

# %%
#Success of a terrorist attack
df['success'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.countplot(df['success'])
plt.title("Success of incident")
# Out:
# Text(0.5, 1.0, 'Success of incident')

# %%
crosstab=pd.crosstab(df.success,df.iyear)
crosstab
# Out:
# iyear    1970  1971  1972  1973  1974  1975  1976  1977  1978  1979  ...  \
# success                                                              ...
# 0         102    51   116    40    36    35    62   128   115   254  ...
# 1         549   420   452   433   545   705   861  1191  1411  2408  ...
#
# iyear    2008  2009  2010  2011  2012   2013   2014   2015   2016  2017
# success
# 0         403   291   441   470   922   1552   1888   2289   2612  2248
# 1        4402  4430  4385  4606  7600  10484  15015  12676  10975  8652
#
# [2 rows x 47 columns]

# %%
#Weapon type of terrorist attack
#1.Biological
#2.chemical
#3.Radiological
#4.Nuclear
#5.Firearms
#6.Explosives
#7.Fake weapons
#8.Incendiary
#9.Melee
#10.Vehicle
#11Sabotage Equiplment
#12Other
#13unknown
df['weaptype1'].unique()
# Out:
# array([13,  6,  8,  5,  2,  9, 11, 10,  7,  3, 12,  1], dtype=int64)

# %%
sns.countplot(df['weaptype1'])
plt.title('Weapon for attack')
# Out:
# Text(0.5, 1.0, 'Weapon for attack')

# %%
df['targtype1'].unique()
# Out:
# array([14,  7, 10,  3, 21,  4,  2,  6,  1,  8, 22, 15, 20, 19, 18, 12, 16,
#         9, 17, 13, 11,  5], dtype=int64)

# %%
sns.countplot(df['targtype1'])
plt.title('Targets of attacks')
# Out:
# Text(0.5, 1.0, 'Targets of attacks')

# %%
df['nperps'].max()
# Out:
# 25000.0

# %%
df[df['nperps']==df['nperps'].max()].set_index('nperps')
#the attack on Bangladesh has max no. of perperators
# Out:
#               eventid  iyear  imonth  iday approxdate  extended resolution  \
# nperps
# 25000.0  199409100003   1994       9    10        NaN         0        NaN
#
#          country country_txt  region  ... addnotes scite1 scite2  scite3  \
# nperps                                ...
# 25000.0       19  Bangladesh       6  ...      NaN    NaN    NaN     NaN
#
#          dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# nperps
# 25000.0      PGIS       -9        -9        0      -9      NaN
#
# [1 rows x 134 columns]

# %%
df[df['nperps']==df['nperps'].min()].set_index('nperps')
#atleast 11 or unknown or if the prepatrors not reported then -99.0 is given to that row
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# nperps
# -99.0   197001010002   1970       1     1        NaN         0        NaN
# -99.0   197001020002   1970       1     2        NaN         0        NaN
# -99.0   197001060001   1970       1     6        NaN         0        NaN
# -99.0   197001090001   1970       1     9        NaN         0        NaN
# -99.0   197001090002   1970       1     9        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# -99.0   201712310022   2017      12    31        NaN         0        NaN
# -99.0   201712310029   2017      12    31        NaN         0        NaN
# -99.0   201712310030   2017      12    31        NaN         0        NaN
# -99.0   201712310031   2017      12    31        NaN         0        NaN
# -99.0   201712310032   2017      12    31        NaN         0        NaN
#
#         country    country_txt  region  ...  \
# ...

# %%
sns.countplot(df['claimed'])
plt.title('Claims of responsibility of attack taken or not unknown')
#claims are not taken mostly
#more than 80000,the responsibility of attach was not taken
# Out:
# Text(0.5, 1.0, 'Claims of responsibility of attack taken or not unknown')

# %%
sns.boxplot(df['nkill'])
# Out:
# <AxesSubplot:xlabel='nkill'>

# %%
df[df['country_txt']=='India']
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1186    197202220004   1972       2    22        NaN         0        NaN
# 2764    197501190004   1975       1     2        NaN         0        NaN
# 3857    197605260001   1976       5    26        NaN         0        NaN
# 5327    197709280004   1977       9    28        NaN         0        NaN
# 7337    197901130004   1979       1    13        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181663  201712300021   2017      12    30        NaN         0        NaN
# 181665  201712300023   2017      12    30        NaN         0        NaN
# 181672  201712310005   2017      12    31        NaN         0        NaN
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
#
#         country country_txt  region  ...  \
# ...

# %%
df[df['iyear']>2000].shape
#these many events took plave after 2000.
# Out:
# (110041, 135)

# %%
events_after_2000=df[df['iyear']>2000]

# %%
plt.figure(figsize=(10,8))
sns.countplot(events_after_2000['iyear'])
plt.title('Number of series of events after year 2000')
# Out:
# Text(0.5, 1.0, 'Number of series of events after year 2000')

# %%
sns.countplot(df['ishostkid'])
plt.title('Observation of no. of events the hostages happened')
# Out:
# Text(0.5, 1.0, 'Observation of no. of events the hostages happened')

# %%
sns.countplot(df['INT_LOG'])
# Out:
# <AxesSubplot:xlabel='INT_LOG', ylabel='count'>

# %%
#1. Attempted Rescue
#2.Hostages released by perperators
#3.Hostages escaped
#4.Hostages killed
#5.Successfull rescue
#6.Combination
#7.Unknown
sns.countplot(df['hostkidoutcome'])
plt.title('Observation of number of hostages rescued or not')
# Out:
# Text(0.5, 1.0, 'Observation of number of hostages rescued or not')

# %% [markdown]
# ## Conclusions:

# %% [markdown]
# 1.Middle east and  North africa,  follwed by South Asia are the hottest region of Terroristy Attack.
#
# 2.Bombing and Explosion are the most common type of attacks.
#
# 3.Year 2014, in recent years has been most infamous year interms of terrorist attack.
#
# 4.In most of the case hostages are released by perparators either after negotiation or success.
